# %%
import pandas as pd
import numpy as np
from faker import Faker
import matplotlib.pyplot as plt

# %%
def generate_fake_data(num_customers, max_repeats):
  fake = Faker()
  data = []

  for _ in range(num_customers):
    customer_id = fake.random_int(min=1000, max=9999)
    first_name = fake.first_name()
    last_name = fake.last_name()
    country = fake.country()
    age = fake.random_int(min=18, max=80)
    gender = fake.random_element(elements=('Male', 'Female'))
    income_level = fake.random_int(min=20000, max=150000)

    for _ in range(fake.random_int(min=1, max=max_repeats)):
      data.append([customer_id, first_name, last_name, country, age, gender, income_level])

  df = pd.DataFrame(data, columns=['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender', 'income_level'])
  return df

# Example usage:
num_customers = 5000
max_repeats = 15
fake_data = generate_fake_data(num_customers, max_repeats)
fake_data = fake_data[:5000]
print(fake_data)
# Out:
#       customer_id first_name last_name    country  age  gender  income_level
# 0            5802   Kimberly    Campos      Kenya   37  Female         52701
# 1            5802   Kimberly    Campos      Kenya   37  Female         52701
# 2            5802   Kimberly    Campos      Kenya   37  Female         52701
# 3            5802   Kimberly    Campos      Kenya   37  Female         52701
# 4            5802   Kimberly    Campos      Kenya   37  Female         52701
# ...           ...        ...       ...        ...  ...     ...           ...
# 4995         2187      Tracy    Kelley  Sri Lanka   22    Male        145999
# 4996         2187      Tracy    Kelley  Sri Lanka   22    Male        145999
# 4997         2187      Tracy    Kelley  Sri Lanka   22    Male        145999
# 4998         2187      Tracy    Kelley  Sri Lanka   22    Male        145999
# 4999         2187      Tracy    Kelley  Sri Lanka   22    Male        145999
#
# [5000 rows x 7 columns]

# %%
def shuffle_data(df):
    # Create a unique identifier for each customer
    df['customer_group'] = df.groupby(['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender', 'income_level']).ngroup()

    # Shuffle the DataFrame
    df = df.sample(frac=1)

    # Drop the temporary customer_group column
    df.drop(columns=['customer_group'], inplace=True)

    return df

# %%
fake_data_1 = shuffle_data(fake_data)

# %%
def generate_customer_data(num_rows):
  fake = Faker()
  
  data = {
      'Winning_percentage':np.random.randint(5,80,size=num_rows),
      'Days_Since_Last_Bet':np.random.randint(1,40,size=num_rows)
  }
  df = pd.DataFrame(data)
  return df
num_rows = 5000
df1 = generate_customer_data(num_rows)
print(df1.head())
# Out:
#    Winning_percentage  Days_Since_Last_Bet
# 0                  45                   29
# 1                  21                   25
# 2                  63                   36
# 3                   9                   27
# 4                  77                   23

# %%
df = pd.concat([fake_data_1,df1],axis=1)

# %%
df.head()
# Out:
#       customer_id first_name last_name    country  age  gender  income_level  \
# 2957         9732      Angel    Nelson      Nauru   41  Female        122531
# 4116         9304      Craig    Obrien  Lithuania   27  Female         55152
# 1904         7999    Rachael    Hinton      China   61  Female         65940
# 4897         2543        Amy     Perez    Algeria   78  Female        112684
# 3303         2021      Linda   Stevens    Tokelau   69    Male         51871
#
#       Winning_percentage  Days_Since_Last_Bet
# 2957                  34                    9
# 4116                  38                   37
# 1904                  42                   37
# 4897                  58                   20
# 3303                  70                   35

# %%
def generate_right_skewed_integers(num_samples, min_val, max_val, scale_factor=10):
  data = np.random.exponential(scale=scale_factor, size=num_samples)
  data = data / data.max() * (max_val - min_val) + min_val
  data = np.rint(data).astype(int)
  return data

# %%
num_samples = 5000
min_val = 100
max_val = 100000
df["Total_Amount_wagered"] = generate_right_skewed_integers(num_samples, min_val, max_val, scale_factor=5)
print(df["Total_Amount_wagered"])
# Out:
# 958     23332
# 4587     9468
# 4061     2466
# 1255    24609
# 212      6083
#         ...
# 1456     2426
# 1411    25851
# 1112     2006
# 4566     1747
# 2035     2007
# Name: Total_Amount_wagered, Length: 5000, dtype: int32

# %%
num_samples = 5000
min_val = 10
max_val = 1000
df["Average_Bet_Amount"] = generate_right_skewed_integers(num_samples, min_val, max_val, scale_factor=5)
print(df["Average_Bet_Amount"])
# Out:
# 3227     12
# 2948    272
# 2042    103
# 211     178
# 3667     20
#        ...
# 4416     28
# 1237    171
# 4052    130
# 1465     39
# 981      96
# Name: Average_Bet_Amount, Length: 5000, dtype: int32

# %%
data = pd.read_csv("my_data_3.csv")

# %%
data["Bet_frequency"].value_counts()
# Out:
# Bet_frequency
# Monthly         1589
# Weekly          1504
# Daily           1009
# Occasionally     682
# No               216
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

def generate_random_number(feature_value):
  mapping = {
      'Daily': np.random.randint(300, 355),
      'Weekly': np.random.randint(45, 55),
      'Monthly': np.random.randint(7, 15),
      'Occasionally': np.random.randint(5, 10),
      'No': np.random.randint(3,9)
  }
  return mapping.get(feature_value, np.random.randint(0, 1)) 

# Apply the function to create a new column
df['Active_Days'] = data['Bet_frequency'].apply(generate_random_number)

print(df['Active_Days'] )
# Out:
# 2957    318
# 4116      8
# 1904     11
# 4897    305
# 3303      7
#        ...
# 2635    322
# 69        7
# 1647     46
# 3762      8
# 3269     12
# Name: Active_Days, Length: 5000, dtype: int64

# %%
df.head()
# Out:
#       customer_id first_name last_name    country  age  gender  income_level  \
# 2957         9732      Angel    Nelson      Nauru   41  Female        122531
# 4116         9304      Craig    Obrien  Lithuania   27  Female         55152
# 1904         7999    Rachael    Hinton      China   61  Female         65940
# 4897         2543        Amy     Perez    Algeria   78  Female        112684
# 3303         2021      Linda   Stevens    Tokelau   69    Male         51871
#
#       Winning_percentage  Days_Since_Last_Bet  Active_Days
# 2957                  34                    9          318
# 4116                  38                   37            8
# 1904                  42                   37           11
# 4897                  58                   20          305
# 3303                  70                   35            7

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender',
#        'income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
#        'Active_Days'],
#       dtype='object')

# %% [markdown]
# Generating correlation with 2 features

# %%
import pandas as pd
import numpy as np

def generate_correlated_feature_2(data, feature1, feature2, correlation_coeff1, correlation_coeff2, noise_level):

  # Extract features as NumPy arrays
  x1 = data[feature1].values
  x2 = data[feature2].values

  # Standardize features
  x1_std = (x1 - np.mean(x1)) / np.std(x1)
  x2_std = (x2 - np.mean(x2)) / np.std(x2)

  # Create correlation matrix
  corr_matrix = np.array([[1, correlation_coeff1], [correlation_coeff1, 1]])

  # Cholesky decomposition
  L = np.linalg.cholesky(corr_matrix)

  # Generate correlated random data
  correlated_data = np.random.randn(len(data), 2) @ L

  # Scale correlated data
  scaled_correlated_data = correlated_data * np.array([np.std(x1), np.std(x2)]) + np.array([np.mean(x1), np.mean(x2)])

  # Create the new feature
  new_feature = scaled_correlated_data[:, 0] + noise_level * np.random.randn(len(data))

  return pd.Series(new_feature, index=data.index)

# %% [markdown]
# Genrating correlation with 3 features

# %%
import numpy as np

def generate_correlated_feature(data, feature1, feature2, feature3, correlation_coeff1, correlation_coeff2, correlation_coeff3, noise_level):
    std1 = np.std(data[feature1])
    std2 = np.std(data[feature2])
    std3 = np.std(data[feature3])
    
    cov12 = correlation_coeff1 * std1 * std2
    cov13 = correlation_coeff1 * std1 * std3
    cov23 = correlation_coeff2 * std2 * std3
    corr_matrix = np.corrcoef(data[[feature1, feature2, feature3]], rowvar=False)
    var_noise = 1 - correlation_coeff1**2 - correlation_coeff2**2 - correlation_coeff3**2 \
               - 2 * (cov12 * corr_matrix[0, 1] + cov13 * corr_matrix[0, 2] + cov23 * corr_matrix[1, 2])
    var_noise = abs(var_noise)
    sigma_noise = np.sqrt(var_noise)
    
    new_feature = correlation_coeff1 * (data[feature1] - np.mean(data[feature1])) / std1 + \
                  correlation_coeff2 * (data[feature2] - np.mean(data[feature2])) / std2 + \
                  correlation_coeff3 * (data[feature3] - np.mean(data[feature3])) / std3 + \
                  sigma_noise * np.random.randn(len(data))
    return new_feature

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender',
#        'income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
#        'Active_Days'],
#       dtype='object')

# %%
df["Total_Number_of_Bets"]= generate_correlated_feature(df,"income_level","Active_Days","Days_Since_Last_Bet",0.7,0.8,-0.8, 0.9)

# %%
df["Total_Amount_Wagered"] = generate_correlated_feature_2(df,'income_level','Total_Number_of_Bets',0.7,0.8,0.9)

# %%
df[["Total_Number_of_Bets","Total_Amount_Wagered"]].corr()
# Out:
#                       Total_Number_of_Bets  Total_Amount_Wagered
# Total_Number_of_Bets              1.000000             -0.019307
# Total_Amount_Wagered             -0.019307              1.000000

# %%
df["Average_Bet_Amount"] = generate_correlated_feature_2(df,'Total_Amount_Wagered','Total_Number_of_Bets',0.4,0.3,0.9)

# %%
df["Number_of_Bonuses_Received"] = generate_correlated_feature_2(df,'Total_Amount_Wagered','Average_Bet_Amount',0.4,0.4,0.9)

# %%
df["Amount_of_Bonuses_Received"] = generate_correlated_feature_2(df,'Average_Bet_Amount','Number_of_Bonuses_Received',0.4,0.5,0.9)

# %%
df["Revenue_from_Bonuses"] = generate_correlated_feature_2(df,'Average_Bet_Amount','Amount_of_Bonuses_Received',0.4,0.5,0.9)

# %%
df["Increase_in_bets_after_bonus"] = generate_correlated_feature_2(df,'Revenue_from_Bonuses','Amount_of_Bonuses_Received',0.4,0.5,0.9)

# %%
df["Increase_in_wagering_after_bonus"] = generate_correlated_feature_2(df,'Increase_in_bets_after_bonus','Number_of_Bonuses_Received',0.4,0.5,0.9)

# %%
df["bonus_1"] = generate_correlated_feature_2(df,"income_level","Winning_percentage",.7,.6,.9)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender',
#        'income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
#        'Active_Days', 'Total_Number_of_Bets', 'Total_Amount_Wagered',
#        'Average_Bet_Amount', 'Number_of_Bonuses_Received',
#        'Amount_of_Bonuses_Received', 'Revenue_from_Bonuses',
#        'Increase_in_bets_after_bonus', 'Increase_in_wagering_after_bonus',
#        'bonus_1'],
#       dtype='object')

# %%
df["bonus_2"] = generate_correlated_feature_2(df,"bonus_1","Days_Since_Last_Bet",.7,.6,.9)

# %%
df["bonus_3"] = generate_correlated_feature_2(df,"bonus_2","Active_Days",.7,.8,.9)

# %%
df["bonus_4"] = generate_correlated_feature_2(df,"bonus_3","Total_Number_of_Bets",.7,.6,.9)

# %%
df["bonus_5"] = generate_correlated_feature_2(df,"bonus_4","Total_Amount_Wagered",.7,.8,.9)

# %%
df["bonus_6"] = generate_correlated_feature_2(df,"bonus_5","Average_Bet_Amount",.7,.8,.9)

# %%
df["bonus_7"] = generate_correlated_feature_2(df,"bonus_6","Number_of_Bonuses_Received",.7,.8,.9)

# %%
df["bonus_8"] = generate_correlated_feature_2(df,"bonus_7","Amount_of_Bonuses_Received",.7,.8,.9)

# %%
df["bonus_9"] = generate_correlated_feature_2(df,"bonus_8","Revenue_from_Bonuses",.7,.8,.9)

# %%
df["bonus_10"] = generate_correlated_feature_2(df,"bonus_9","Increase_in_bets_after_bonus",.7,.8,.9)

# %%
df["bonus_11"] = generate_correlated_feature_2(df,"bonus_10","Increase_in_wagering_after_bonus",.7,.8,.9)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender',
#        'income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
#        'Active_Days', 'Total_Number_of_Bets', 'Total_Amount_Wagered',
#        'Average_Bet_Amount', 'Number_of_Bonuses_Received',
#        'Amount_of_Bonuses_Received', 'Revenue_from_Bonuses',
#        'Increase_in_bets_after_bonus', 'Increase_in_wagering_after_bonus',
#        'bonus_1', 'bonus_2', 'bonus_3', 'bonus_4', 'bonus_5', 'bonus_6',
#        'bonus_7', 'bonus_8', 'bonus_9', 'bonus_10', 'bonus_11'],
#       dtype='object')

# %%
df_2 = df[['income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
       'Active_Days', 'Total_Number_of_Bets', 'Total_Amount_Wagered',
       'Average_Bet_Amount', 'Number_of_Bonuses_Received',
       'Amount_of_Bonuses_Received', 'Revenue_from_Bonuses',
       'Increase_in_bets_after_bonus', 'Increase_in_wagering_after_bonus',
       'bonus_1', 'bonus_2', 'bonus_3', 'bonus_4', 'bonus_5', 'bonus_6',
       'bonus_7', 'bonus_8', 'bonus_9', 'bonus_10', 'bonus_11']]

# %%
df_2.corr()
# Out:
#                                   income_level  Winning_percentage  \
# income_level                          1.000000           -0.006477
# Winning_percentage                   -0.006477            1.000000
# Days_Since_Last_Bet                   0.008944           -0.005999
# Active_Days                          -0.005223            0.013035
# Total_Number_of_Bets                  0.004382            0.008414
# Total_Amount_Wagered                  0.009988           -0.025391
# Average_Bet_Amount                    0.022416            0.016000
# Number_of_Bonuses_Received           -0.006134            0.004580
# Amount_of_Bonuses_Received            0.003729           -0.007019
# Revenue_from_Bonuses                 -0.038314            0.030052
# Increase_in_bets_after_bonus          0.015965           -0.013473
# Increase_in_wagering_after_bonus      0.003373           -0.004401
# bonus_1                              -0.003168            0.012563
# bonus_2                               0.009429           -0.001840
# bonus_3                               0.005596            0.038102
# bonus_4                              -0.003487            0.001343
# bonus_5                              -0.004183           -0.019818
# bonus_6                               0.003642            0.008291
# bonus_7                               0.001951            0.010796
# bonus_8                               0.002652           -0.024550
# bonus_9                              -0.008461           -0.002446
# bonus_10                              0.000819            0.000883
# bonus_11                             -0.001533            0.010780
#
#                                   Days_Since_Last_Bet  Active_Days  \
# income_level                                 0.008944    -0.005223
# Winning_percentage                          -0.005999     0.013035
# Days_Since_Last_Bet                          1.000000    -0.001854
# Active_Days                                 -0.001854     1.000000
# Total_Number_of_Bets                        -0.009093     0.006804
# Total_Amount_Wagered                        -0.001036    -0.023326
# Average_Bet_Amount                           0.000646     0.000296
# Number_of_Bonuses_Received                   0.000926     0.003047
# Amount_of_Bonuses_Received                  -0.000876     0.008585
# Revenue_from_Bonuses                        -0.004529    -0.009072
# Increase_in_bets_after_bonus                -0.005945     0.006487
# Increase_in_wagering_after_bonus             0.029131    -0.037768
# bonus_1                                     -0.024799    -0.037729
# bonus_2                                     -0.007052    -0.002210
# bonus_3                                     -0.005137     0.021387
# bonus_4                                      0.004986     0.017985
# bonus_5                                      0.010753     0.010353
# bonus_6                                     -0.006011    -0.029824
# bonus_7                                      0.018146    -0.004805
# bonus_8                                      0.017988     0.004760
# bonus_9                                      0.006943    -0.000541
# bonus_10                                     0.017849     0.001218
# bonus_11                                    -0.002647     0.004280
#
#                                   Total_Number_of_Bets  Total_Amount_Wagered  \
# income_level                                  0.004382              0.009988
# Winning_percentage                            0.008414             -0.025391
# Days_Since_Last_Bet                          -0.009093             -0.001036
# Active_Days                                   0.006804             -0.023326
# Total_Number_of_Bets                          1.000000             -0.021593
# Total_Amount_Wagered                         -0.021593              1.000000
# Average_Bet_Amount                            0.000808              0.003263
# Number_of_Bonuses_Received                   -0.017762              0.004987
# Amount_of_Bonuses_Received                    0.002621              0.015856
# Revenue_from_Bonuses                          0.025977             -0.006305
# Increase_in_bets_after_bonus                  0.001911              0.032952
# Increase_in_wagering_after_bonus             -0.002192             -0.001111
# bonus_1                                      -0.020769              0.021249
# bonus_2                                      -0.005076              0.001224
# bonus_3                                      -0.017395             -0.005786
# bonus_4                                      -0.001482             -0.006532
# bonus_5                                       0.011081             -0.003935
# bonus_6                                       0.010632              0.009125
# bonus_7                                       0.014330             -0.007814
# bonus_8                                      -0.016833              0.008931
# bonus_9                                       0.013372             -0.014590
# bonus_10                                      0.012475             -0.001716
# bonus_11                                      0.031712             -0.004970
#
#                                   Average_Bet_Amount  \
# income_level                                0.022416
# Winning_percentage                          0.016000
# Days_Since_Last_Bet                         0.000646
# Active_Days                                 0.000296
# Total_Number_of_Bets                        0.000808
# Total_Amount_Wagered                        0.003263
# Average_Bet_Amount                          1.000000
# Number_of_Bonuses_Received                 -0.016503
# Amount_of_Bonuses_Received                  0.005827
# Revenue_from_Bonuses                        0.015454
# Increase_in_bets_after_bonus               -0.027880
# Increase_in_wagering_after_bonus            0.004402
# bonus_1                                     0.001880
# bonus_2                                    -0.008956
# bonus_3                                    -0.003633
# bonus_4                                    -0.026382
# bonus_5                                    -0.023750
# bonus_6                                     0.033536
# bonus_7                                     0.007884
# bonus_8                                     0.000593
# bonus_9                                     0.004620
# bonus_10                                   -0.023115
# bonus_11                                    0.005700
#
#                                   Number_of_Bonuses_Received  \
# income_level                                       -0.006134
# Winning_percentage                                  0.004580
# Days_Since_Last_Bet                                 0.000926
# Active_Days                                         0.003047
# Total_Number_of_Bets                               -0.017762
# Total_Amount_Wagered                                0.004987
# Average_Bet_Amount                                 -0.016503
# Number_of_Bonuses_Received                          1.000000
# Amount_of_Bonuses_Received                          0.013027
# Revenue_from_Bonuses                               -0.008745
# Increase_in_bets_after_bonus                        0.002695
# Increase_in_wagering_after_bonus                    0.006664
# bonus_1                                             0.011976
# bonus_2                                             0.010180
# bonus_3                                             0.001468
# bonus_4                                             0.001073
# bonus_5                                             0.000946
# bonus_6                                             0.004224
# bonus_7                                            -0.021540
# bonus_8                                             0.025277
# bonus_9                                            -0.010811
# bonus_10                                            0.000016
# bonus_11                                           -0.002510
#
#                                   Amount_of_Bonuses_Received  \
# income_level                                        0.003729
# Winning_percentage                                 -0.007019
# Days_Since_Last_Bet                                -0.000876
# Active_Days                                         0.008585
# Total_Number_of_Bets                                0.002621
# Total_Amount_Wagered                                0.015856
# Average_Bet_Amount                                  0.005827
# Number_of_Bonuses_Received                          0.013027
# Amount_of_Bonuses_Received                          1.000000
# Revenue_from_Bonuses                                0.024405
# Increase_in_bets_after_bonus                       -0.022052
# Increase_in_wagering_after_bonus                    0.011276
# bonus_1                                            -0.013771
# bonus_2                                             0.005090
# bonus_3                                             0.013123
# bonus_4                                             0.002777
# bonus_5                                            -0.012541
# bonus_6                                             0.005397
# bonus_7                                             0.011542
# bonus_8                                             0.007587
# bonus_9                                             0.003757
# bonus_10                                            0.018099
# bonus_11                                           -0.015324
#
#                                   Revenue_from_Bonuses  ...   bonus_2  \
# income_level                                 -0.038314  ...  0.009429
# Winning_percentage                            0.030052  ... -0.001840
# Days_Since_Last_Bet                          -0.004529  ... -0.007052
# Active_Days                                  -0.009072  ... -0.002210
# Total_Number_of_Bets                          0.025977  ... -0.005076
# Total_Amount_Wagered                         -0.006305  ...  0.001224
# Average_Bet_Amount                            0.015454  ... -0.008956
# Number_of_Bonuses_Received                   -0.008745  ...  0.010180
# Amount_of_Bonuses_Received                    0.024405  ...  0.005090
# Revenue_from_Bonuses                          1.000000  ...  0.007384
# Increase_in_bets_after_bonus                  0.013716  ... -0.019834
# Increase_in_wagering_after_bonus             -0.022742  ... -0.005674
# bonus_1                                      -0.012932  ... -0.012076
# bonus_2                                       0.007384  ...  1.000000
# bonus_3                                      -0.012001  ...  0.016919
# bonus_4                                       0.020188  ...  0.011020
# bonus_5                                       0.005574  ...  0.010161
# bonus_6                                      -0.006436  ...  0.003037
# bonus_7                                       0.012427  ...  0.015897
# bonus_8                                       0.012329  ... -0.008178
# bonus_9                                       0.000504  ...  0.024847
# bonus_10                                     -0.000112  ... -0.009027
# bonus_11                                      0.010392  ...  0.011054
#
#                                    bonus_3   bonus_4   bonus_5   bonus_6  \
# income_level                      0.005596 -0.003487 -0.004183  0.003642
# Winning_percentage                0.038102  0.001343 -0.019818  0.008291
# Days_Since_Last_Bet              -0.005137  0.004986  0.010753 -0.006011
# Active_Days                       0.021387  0.017985  0.010353 -0.029824
# Total_Number_of_Bets             -0.017395 -0.001482  0.011081  0.010632
# Total_Amount_Wagered             -0.005786 -0.006532 -0.003935  0.009125
# Average_Bet_Amount               -0.003633 -0.026382 -0.023750  0.033536
# Number_of_Bonuses_Received        0.001468  0.001073  0.000946  0.004224
# Amount_of_Bonuses_Received        0.013123  0.002777 -0.012541  0.005397
# Revenue_from_Bonuses             -0.012001  0.020188  0.005574 -0.006436
# Increase_in_bets_after_bonus      0.004868 -0.001070 -0.001907  0.027816
# Increase_in_wagering_after_bonus  0.021353 -0.007244 -0.009535  0.002193
# bonus_1                           0.011967 -0.024260 -0.005413  0.021232
# bonus_2                           0.016919  0.011020  0.010161  0.003037
# bonus_3                           1.000000 -0.014731 -0.010450 -0.005274
# bonus_4                          -0.014731  1.000000  0.023326 -0.006516
# bonus_5                          -0.010450  0.023326  1.000000  0.016280
# bonus_6                          -0.005274 -0.006516  0.016280  1.000000
# bonus_7                           0.005817  0.017599 -0.016304 -0.017740
# bonus_8                          -0.016202 -0.008926 -0.033414 -0.002720
# bonus_9                           0.007758 -0.017530  0.013449 -0.011806
# bonus_10                         -0.012060  0.008586 -0.005004 -0.005635
# bonus_11                         -0.000632 -0.000454 -0.005666 -0.003377
#
#                                    bonus_7   bonus_8   bonus_9  bonus_10  \
# income_level                      0.001951  0.002652 -0.008461  0.000819
# Winning_percentage                0.010796 -0.024550 -0.002446  0.000883
# Days_Since_Last_Bet               0.018146  0.017988  0.006943  0.017849
# Active_Days                      -0.004805  0.004760 -0.000541  0.001218
# Total_Number_of_Bets              0.014330 -0.016833  0.013372  0.012475
# Total_Amount_Wagered             -0.007814  0.008931 -0.014590 -0.001716
# Average_Bet_Amount                0.007884  0.000593  0.004620 -0.023115
# Number_of_Bonuses_Received       -0.021540  0.025277 -0.010811  0.000016
# Amount_of_Bonuses_Received        0.011542  0.007587  0.003757  0.018099
# Revenue_from_Bonuses              0.012427  0.012329  0.000504 -0.000112
# Increase_in_bets_after_bonus     -0.006868 -0.024601 -0.006218 -0.003801
# Increase_in_wagering_after_bonus -0.007577  0.032685  0.004695  0.029379
# bonus_1                          -0.016465 -0.000521  0.012918 -0.006285
# bonus_2                           0.015897 -0.008178  0.024847 -0.009027
# bonus_3                           0.005817 -0.016202  0.007758 -0.012060
# bonus_4                           0.017599 -0.008926 -0.017530  0.008586
# bonus_5                          -0.016304 -0.033414  0.013449 -0.005004
# bonus_6                          -0.017740 -0.002720 -0.011806 -0.005635
# bonus_7                           1.000000  0.004167  0.004365  0.018511
# bonus_8                           0.004167  1.000000 -0.017407  0.003855
# bonus_9                           0.004365 -0.017407  1.000000 -0.014101
# bonus_10                          0.018511  0.003855 -0.014101  1.000000
# bonus_11                          0.023171 -0.004071 -0.015790  0.001553
#
#                                   bonus_11
# income_level                     -0.001533
# Winning_percentage                0.010780
# Days_Since_Last_Bet              -0.002647
# Active_Days                       0.004280
# Total_Number_of_Bets              0.031712
# Total_Amount_Wagered             -0.004970
# Average_Bet_Amount                0.005700
# Number_of_Bonuses_Received       -0.002510
# Amount_of_Bonuses_Received       -0.015324
# Revenue_from_Bonuses              0.010392
# Increase_in_bets_after_bonus      0.011004
# Increase_in_wagering_after_bonus -0.011201
# bonus_1                           0.017107
# bonus_2                           0.011054
# bonus_3                          -0.000632
# bonus_4                          -0.000454
# bonus_5                          -0.005666
# bonus_6                          -0.003377
# bonus_7                           0.023171
# bonus_8                          -0.004071
# bonus_9                          -0.015790
# bonus_10                          0.001553
# bonus_11                          1.000000
#
# [23 rows x 23 columns]

# %%
df["Average_Bet_Amount"] = min_max_scaling(df["Average_Bet_Amount"], 10, 1000)
df["Average_Bet_Amount"] = round(df["Average_Bet_Amount"])

# %%
df["Total_Amount_Wagered"] = min_max_scaling(df["Total_Amount_Wagered"], 100, 100000)
df["Total_Amount_Wagered"] = round(df["Total_Amount_Wagered"])

# %%
df["Number_of_Bonuses_Received"] = min_max_scaling(df["Number_of_Bonuses_Received"], 1, 100)
df["Number_of_Bonuses_Received"] = round(df["Number_of_Bonuses_Received"])

# %%
df["Amount_of_Bonuses_Received"] = min_max_scaling(df["Amount_of_Bonuses_Received"], 10, 1000)
df["Amount_of_Bonuses_Received"] = round(df["Amount_of_Bonuses_Received"])

# %%
df["Revenue_from_Bonuses"] = min_max_scaling(df["Revenue_from_Bonuses"], 10, 5000)
df["Revenue_from_Bonuses"] = round(df["Revenue_from_Bonuses"])

# %%
df["Increase_in_bets_after_bonus"] = min_max_scaling(df["Increase_in_bets_after_bonus"], 30, 500)
df["Increase_in_bets_after_bonus"] = round(df["Increase_in_bets_after_bonus"])

# %%
df["Increase_in_wagering_after_bonus"] = min_max_scaling(df["Increase_in_wagering_after_bonus"], 100, 50000)
df["Increase_in_wagering_after_bonus"] = round(df["Increase_in_wagering_after_bonus"])

# %%
df["bonus_11"] = min_max_scaling(df["bonus_11"], 10, 500)
df["bonus_11"] = round(df["bonus_11"])

# %%
import numpy as np

def min_max_scaling(feature, new_min, new_max):
  min_val = np.min(feature)
  max_val = np.max(feature)
  scaled_feature = (feature - min_val) / (max_val - min_val) * (new_max - new_min) + new_min
  return scaled_feature

# %%
df["Total_Number_of_Bets"] = min_max_scaling(df["Total_Number_of_Bets"], 1, 50)
df["Total_Number_of_Bets"] = round(df["Total_Number_of_Bets"])

# %%
df["Should_Receive_Bonus"] = [1 if i > 263 else 0 for i in df["bonus_11"]]

# %%
df["Should_Receive_Bonus"].value_counts()
# Out:
# Should_Receive_Bonus
# 1    2874
# 0    2126
# Name: count, dtype: int64

# %%
df["bonus_12"].value_counts()
# Out:
# bonus_12
# 1    2874
# 0    2126
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       customer_id first_name last_name                           country  age  \
# 593          4368      Kevin    Carney                          Portugal   34
# 2736         6093     Robert    Archer                           Senegal   19
# 1800         4970       John    Brooks                              Guam   30
# 4313         9033      Laura     Jones  Saint Vincent and the Grenadines   35
# 2654         9144      Devin    Archer                             Macao   21
#
#       gender  income_level  Winning_percentage  Days_Since_Last_Bet  \
# 593   Female        103037                  48                    8
# 2736  Female        104061                  44                   38
# 1800    Male        125464                  68                    6
# 4313    Male        100702                  59                   13
# 2654  Female        145579                  47                   36
#
#       Active_Days  ...        bonus_4       bonus_5        bonus_6  \
# 593            52  ...  114949.307582  64652.918969   53980.248687
# 2736            9  ...   96801.465646  61013.142461   58664.189058
# 1800           52  ...  117202.753007  90638.520708   91604.834709
# 4313          333  ...  129758.424520  79807.020131  176126.469995
# 2654            9  ...   29464.662088 -14439.523208   71564.798586
#
#             bonus_7        bonus_8        bonus_9      bonus_10  bonus_11  \
# 593   115745.574792    7274.451711  127626.330806  81558.933952     271.0
# 2736   54306.458457  200832.548362  172364.258916 -50527.324489     259.0
# 1800  173577.028655  153145.678223  111177.037042  90262.972486     179.0
# 4313    7242.171362  136636.084807   61609.200967  59814.811206     221.0
# 2654  242973.488933   58941.887779  112287.459037  48980.326151     377.0
#
#       bonus_12  Should_Receive_Bonus
# 593          1                     1
# 2736         0                     0
# 1800         0                     0
# 4313         0                     0
# 2654         1                     1
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'country', 'age', 'gender',
#        'income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
#        'Active_Days', 'Total_Number_of_Bets', 'Total_Amount_Wagered',
#        'Average_Bet_Amount', 'Number_of_Bonuses_Received',
#        'Amount_of_Bonuses_Received', 'Revenue_from_Bonuses',
#        'Increase_in_bets_after_bonus', 'Increase_in_wagering_after_bonus',
#        'bonus_1', 'bonus_2', 'bonus_3', 'bonus_4', 'bonus_5', 'bonus_6',
#        'bonus_7', 'bonus_8', 'bonus_9', 'bonus_10', 'bonus_11', 'bonus_12',
#        'Should_Receive_Bonus'],
#       dtype='object')

# %%
df_1 = df[['income_level', 'Winning_percentage', 'Days_Since_Last_Bet',
       'Active_Days', 'Total_Number_of_Bets', 'Total_Amount_Wagered',
       'Average_Bet_Amount', 'Number_of_Bonuses_Received',
       'Amount_of_Bonuses_Received', 'Revenue_from_Bonuses',
       'Increase_in_bets_after_bonus', 'Increase_in_wagering_after_bonus',"bonus_9",'Should_Receive_Bonus']]

# %%
df_1.corr()
# Out:
#                                   income_level  Winning_percentage  \
# income_level                          1.000000           -0.018131
# Winning_percentage                   -0.018131            1.000000
# Days_Since_Last_Bet                   0.005164           -0.004752
# Active_Days                          -0.004691            0.011731
# Total_Number_of_Bets                 -0.015886            0.000853
# Total_Amount_Wagered                 -0.002175            0.002476
# Average_Bet_Amount                   -0.015634            0.020975
# Number_of_Bonuses_Received           -0.004961            0.003078
# Amount_of_Bonuses_Received           -0.019064           -0.016736
# Revenue_from_Bonuses                 -0.025982           -0.009707
# Increase_in_bets_after_bonus         -0.013763           -0.015868
# Increase_in_wagering_after_bonus     -0.017245           -0.000798
# bonus_9                               0.027458            0.038475
# Should_Receive_Bonus                  0.009155            0.003728
#
#                                   Days_Since_Last_Bet  Active_Days  \
# income_level                                 0.005164    -0.004691
# Winning_percentage                          -0.004752     0.011731
# Days_Since_Last_Bet                          1.000000     0.005175
# Active_Days                                  0.005175     1.000000
# Total_Number_of_Bets                        -0.016779     0.023409
# Total_Amount_Wagered                         0.013049     0.021611
# Average_Bet_Amount                           0.018901     0.006172
# Number_of_Bonuses_Received                  -0.013783     0.015508
# Amount_of_Bonuses_Received                   0.008406     0.006811
# Revenue_from_Bonuses                         0.017307    -0.001979
# Increase_in_bets_after_bonus                 0.015064     0.021937
# Increase_in_wagering_after_bonus            -0.000581     0.011885
# bonus_9                                      0.005813     0.007175
# Should_Receive_Bonus                         0.025530     0.012917
#
#                                   Total_Number_of_Bets  Total_Amount_Wagered  \
# income_level                                 -0.015886             -0.002175
# Winning_percentage                            0.000853              0.002476
# Days_Since_Last_Bet                          -0.016779              0.013049
# Active_Days                                   0.023409              0.021611
# Total_Number_of_Bets                          1.000000             -0.014065
# Total_Amount_Wagered                         -0.014065              1.000000
# Average_Bet_Amount                            0.010291             -0.013976
# Number_of_Bonuses_Received                    0.011282              0.008699
# Amount_of_Bonuses_Received                    0.000598             -0.011438
# Revenue_from_Bonuses                         -0.018547             -0.007429
# Increase_in_bets_after_bonus                  0.011191             -0.000485
# Increase_in_wagering_after_bonus              0.007211             -0.004079
# bonus_9                                       0.002453             -0.000744
# Should_Receive_Bonus                          0.014331              0.002111
#
#                                   Average_Bet_Amount  \
# income_level                               -0.015634
# Winning_percentage                          0.020975
# Days_Since_Last_Bet                         0.018901
# Active_Days                                 0.006172
# Total_Number_of_Bets                        0.010291
# Total_Amount_Wagered                       -0.013976
# Average_Bet_Amount                          1.000000
# Number_of_Bonuses_Received                  0.003569
# Amount_of_Bonuses_Received                 -0.015422
# Revenue_from_Bonuses                        0.024526
# Increase_in_bets_after_bonus                0.012790
# Increase_in_wagering_after_bonus            0.000744
# bonus_9                                    -0.003061
# Should_Receive_Bonus                       -0.005346
#
#                                   Number_of_Bonuses_Received  \
# income_level                                       -0.004961
# Winning_percentage                                  0.003078
# Days_Since_Last_Bet                                -0.013783
# Active_Days                                         0.015508
# Total_Number_of_Bets                                0.011282
# Total_Amount_Wagered                                0.008699
# Average_Bet_Amount                                  0.003569
# Number_of_Bonuses_Received                          1.000000
# Amount_of_Bonuses_Received                          0.006618
# Revenue_from_Bonuses                                0.009843
# Increase_in_bets_after_bonus                       -0.009653
# Increase_in_wagering_after_bonus                   -0.002000
# bonus_9                                            -0.013708
# Should_Receive_Bonus                               -0.023959
#
#                                   Amount_of_Bonuses_Received  \
# income_level                                       -0.019064
# Winning_percentage                                 -0.016736
# Days_Since_Last_Bet                                 0.008406
# Active_Days                                         0.006811
# Total_Number_of_Bets                                0.000598
# Total_Amount_Wagered                               -0.011438
# Average_Bet_Amount                                 -0.015422
# Number_of_Bonuses_Received                          0.006618
# Amount_of_Bonuses_Received                          1.000000
# Revenue_from_Bonuses                                0.006226
# Increase_in_bets_after_bonus                       -0.007658
# Increase_in_wagering_after_bonus                   -0.023519
# bonus_9                                             0.018883
# Should_Receive_Bonus                                0.012763
#
#                                   Revenue_from_Bonuses  \
# income_level                                 -0.025982
# Winning_percentage                           -0.009707
# Days_Since_Last_Bet                           0.017307
# Active_Days                                  -0.001979
# Total_Number_of_Bets                         -0.018547
# Total_Amount_Wagered                         -0.007429
# Average_Bet_Amount                            0.024526
# Number_of_Bonuses_Received                    0.009843
# Amount_of_Bonuses_Received                    0.006226
# Revenue_from_Bonuses                          1.000000
# Increase_in_bets_after_bonus                 -0.000855
# Increase_in_wagering_after_bonus              0.003909
# bonus_9                                      -0.025052
# Should_Receive_Bonus                          0.022974
#
#                                   Increase_in_bets_after_bonus  \
# income_level                                         -0.013763
# Winning_percentage                                   -0.015868
# Days_Since_Last_Bet                                   0.015064
# Active_Days                                           0.021937
# Total_Number_of_Bets                                  0.011191
# Total_Amount_Wagered                                 -0.000485
# Average_Bet_Amount                                    0.012790
# Number_of_Bonuses_Received                           -0.009653
# Amount_of_Bonuses_Received                           -0.007658
# Revenue_from_Bonuses                                 -0.000855
# Increase_in_bets_after_bonus                          1.000000
# Increase_in_wagering_after_bonus                      0.021442
# bonus_9                                              -0.018491
# Should_Receive_Bonus                                 -0.024571
#
#                                   Increase_in_wagering_after_bonus   bonus_9  \
# income_level                                             -0.017245  0.027458
# Winning_percentage                                       -0.000798  0.038475
# Days_Since_Last_Bet                                      -0.000581  0.005813
# Active_Days                                               0.011885  0.007175
# Total_Number_of_Bets                                      0.007211  0.002453
# Total_Amount_Wagered                                     -0.004079 -0.000744
# Average_Bet_Amount                                        0.000744 -0.003061
# Number_of_Bonuses_Received                               -0.002000 -0.013708
# Amount_of_Bonuses_Received                               -0.023519  0.018883
# Revenue_from_Bonuses                                      0.003909 -0.025052
# Increase_in_bets_after_bonus                              0.021442 -0.018491
# Increase_in_wagering_after_bonus                          1.000000 -0.007752
# bonus_9                                                  -0.007752  1.000000
# Should_Receive_Bonus                                     -0.000759  0.024495
#
#                                   Should_Receive_Bonus
# income_level                                  0.009155
# Winning_percentage                            0.003728
# Days_Since_Last_Bet                           0.025530
# Active_Days                                   0.012917
# Total_Number_of_Bets                          0.014331
# Total_Amount_Wagered                          0.002111
# Average_Bet_Amount                           -0.005346
# Number_of_Bonuses_Received                   -0.023959
# Amount_of_Bonuses_Received                    0.012763
# Revenue_from_Bonuses                          0.022974
# Increase_in_bets_after_bonus                 -0.024571
# Increase_in_wagering_after_bonus             -0.000759
# bonus_9                                       0.024495
# Should_Receive_Bonus                          1.000000

# %%
project_data_final = "project_data_final.csv"

# %%
df.to_csv(project_data_final,index=False)

# %%
df.head()
# Out:
#    Customer_id First_name   Last_name    Country  Gender  Age  \
# 0       606778      Tammy    Robinson     Mexico  Female   69
# 1       882088    Timothy       Smith  Argentina    Male   41
# 2       823104       Mary    Mckinney     Mexico  Female   51
# 3       243455      Sarah       White      India  Female   38
# 4       485861     Edward  Stephenson     Brazil    Male   51
#
#    Winning_percentage  Days_Since_Last_Bet  Income_Level_(k)  \
# 0                  76                    3             45124
# 1                  70                    7             36256
# 2                  20                    5             31652
# 3                  77                   19             29271
# 4                  16                   13             44007
#
#    Total_Amount_wagered  ...  Active_Days  Total_Number_of_Bets  \
# 0                  4340  ...           49                  32.0
# 1                 30174  ...           50                  24.0
# 2                  7685  ...           54                  20.0
# 3                   844  ...            7                  32.0
# 4                  3476  ...           48                  29.0
#
#    Total_Amount_Wagered  Number_of_Bonuses_Received  \
# 0               61621.0                        54.0
# 1               14323.0                        39.0
# 2               58136.0                        46.0
# 3               38810.0                        37.0
# 4               54909.0                        48.0
#
#    Amount_of_Bonuses_Received  Revenue_from_Bonuses  \
# 0                       719.0                4312.0
# 1                       402.0                4291.0
# 2                       307.0                2858.0
# 3                       423.0                2534.0
# 4                       460.0                2200.0
#
#    Increase_in_bets_after_bonus  Increase_in_wagering_after_bonus  \
# 0                         217.0                           20241.0
# 1                         332.0                           16955.0
# 2                         281.0                           25409.0
# 3                         273.0                           21905.0
# 4                         360.0                           26404.0
#
#    Should_Receive_Bonus  withdraw_frequency
# 0                     0              Weekly
# 1                     0              Weekly
# 2                     0              Weekly
# 3                     1             Monthly
# 4                     1              Weekly
#
# [5 rows x 21 columns]
