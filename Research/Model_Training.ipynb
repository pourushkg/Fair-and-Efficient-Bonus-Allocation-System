# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve 
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("final_clean_data_2.csv")

# %%
df_1 = pd.read_csv("final_clean_data_3.csv")

# %%
df.head()
# Out:
#    Winning_percentage  Days_Since_Last_Bet  Active_Days  Total_Number_of_Bets  \
# 0                  48                 20.0        220.0                  50.0
# 1                   6                 19.0        220.0                  49.0
# 2                  60                 38.0        300.0                  31.0
# 3                  12                  2.0        126.0                  14.0
# 4                  50                 13.0        343.0                  34.0
#
#    Total_Amount_Wagered  Average_Bet_Amount  Number_of_Bonuses_Received  \
# 0               85884.0               981.0                       100.0
# 1               86247.0               982.0                       100.0
# 2               91475.0               999.0                       100.0
# 3               53581.0               810.0                        96.0
# 4               97661.0               994.0                       100.0
#
#    Amount_of_Bonuses_Received  Revenue_from_Bonuses  \
# 0                      1000.0                5000.0
# 1                      1000.0                5000.0
# 2                      1000.0                5000.0
# 3                       992.0                4982.0
# 4                      1000.0                5000.0
#
#    Increase_in_Bets_After_Bonus  Increase_in_wagering_after_Bonus  \
# 0                         500.0                           50000.0
# 1                         500.0                           50000.0
# 2                         500.0                           50000.0
# 3                         500.0                           49990.0
# 4                         500.0                           50000.0
#
#    Should_Receive_Bonus
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
df_1.head()
# Out:
#    Winning_percentage  Days_Since_Last_Bet  Active_Days  Total_Number_of_Bets  \
# 0                  43                 35.0        365.0                  20.0
# 1                  73                 29.0        184.0                  44.0
# 2                  20                 33.0        184.0                  39.0
# 3                  56                 36.0        322.0                  30.0
# 4                   7                 40.0        322.0                  21.0
#
#    Total_Amount_Wagered  Average_Bet_Amount  Number_of_Bonuses_Received  \
# 0               34454.0               244.0                        40.0
# 1               72327.0               707.0                        76.0
# 2               80154.0               831.0                        92.0
# 3               73397.0               904.0                        88.0
# 4               25629.0               223.0                        51.0
#
#    Amount_of_Bonuses_Received  Revenue_from_Bonuses  \
# 0                       996.0                4964.0
# 1                       735.0                3885.0
# 2                       555.0                3070.0
# 3                       462.0                2478.0
# 4                       984.0                4940.0
#
#    Increase_in_Bets_After_Bonus  Increase_in_wagering_after_Bonus  \
# 0                         159.0                           49938.0
# 1                         257.0                           40259.0
# 2                         321.0                           29574.0
# 3                         353.0                           32232.0
# 4                         164.0                           49385.0
#
#    Should_Receive_Bonus
# 0                     1
# 1                     1
# 2                     0
# 3                     0
# 4                     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Winning_percentage                5000 non-null   int64
#  1   Days_Since_Last_Bet               5000 non-null   float64
#  2   Active_Days                       5000 non-null   float64
#  3   Total_Number_of_Bets              5000 non-null   float64
#  4   Total_Amount_Wagered              5000 non-null   float64
#  5   Average_Bet_Amount                5000 non-null   float64
#  6   Number_of_Bonuses_Received        5000 non-null   float64
#  7   Amount_of_Bonuses_Received        5000 non-null   float64
#  8   Revenue_from_Bonuses              5000 non-null   float64
#  9   Increase_in_Bets_After_Bonus      5000 non-null   float64
#  10  Increase_in_wagering_after_Bonus  5000 non-null   float64
#  11  Should_Receive_Bonus              5000 non-null   int64
# dtypes: float64(10), int64(2)
# memory usage: 468.9 KB

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Winning_percentage                5000 non-null   int64
#  1   Days_Since_Last_Bet               5000 non-null   float64
#  2   Active_Days                       5000 non-null   float64
#  3   Total_Number_of_Bets              5000 non-null   float64
#  4   Total_Amount_Wagered              5000 non-null   float64
#  5   Average_Bet_Amount                5000 non-null   float64
#  6   Number_of_Bonuses_Received        5000 non-null   float64
#  7   Amount_of_Bonuses_Received        5000 non-null   float64
#  8   Revenue_from_Bonuses              5000 non-null   float64
#  9   Increase_in_Bets_After_Bonus      5000 non-null   float64
#  10  Increase_in_wagering_after_Bonus  5000 non-null   float64
#  11  Should_Receive_Bonus              5000 non-null   int64
# dtypes: float64(10), int64(2)
# memory usage: 468.9 KB

# %%
df.corr()
# Out:
#                                   Winning_percentage  Days_Since_Last_Bet  \
# Winning_percentage                          1.000000            -0.020148
# Days_Since_Last_Bet                        -0.020148             1.000000
# Active_Days                                -0.020881             0.002796
# Total_Number_of_Bets                       -0.033563             0.214712
# Total_Amount_Wagered                       -0.014686             0.262416
# Average_Bet_Amount                         -0.021418             0.220054
# Number_of_Bonuses_Received                 -0.020859             0.160583
# Amount_of_Bonuses_Received                 -0.016889             0.110734
# Revenue_from_Bonuses                       -0.014581             0.079984
# Increase_in_Bets_After_Bonus               -0.011880             0.053157
# Increase_in_wagering_after_Bonus           -0.011462             0.051679
# Should_Receive_Bonus                        0.366710             0.100379
#
#                                   Active_Days  Total_Number_of_Bets  \
# Winning_percentage                  -0.020881             -0.033563
# Days_Since_Last_Bet                  0.002796              0.214712
# Active_Days                          1.000000              0.195192
# Total_Number_of_Bets                 0.195192              1.000000
# Total_Amount_Wagered                 0.144408              0.643872
# Average_Bet_Amount                   0.161536              0.536043
# Number_of_Bonuses_Received           0.134548              0.360399
# Amount_of_Bonuses_Received           0.099675              0.229414
# Revenue_from_Bonuses                 0.074916              0.166266
# Increase_in_Bets_After_Bonus         0.052962              0.109312
# Increase_in_wagering_after_Bonus     0.050835              0.106594
# Should_Receive_Bonus                 0.142909             -0.001881
#
#                                   Total_Amount_Wagered  Average_Bet_Amount  \
# Winning_percentage                           -0.014686           -0.021418
# Days_Since_Last_Bet                           0.262416            0.220054
# Active_Days                                   0.144408            0.161536
# Total_Number_of_Bets                          0.643872            0.536043
# Total_Amount_Wagered                          1.000000            0.870453
# Average_Bet_Amount                            0.870453            1.000000
# Number_of_Bonuses_Received                    0.642656            0.892831
# Amount_of_Bonuses_Received                    0.451784            0.715258
# Revenue_from_Bonuses                          0.339687            0.569846
# Increase_in_Bets_After_Bonus                  0.237462            0.431737
# Increase_in_wagering_after_Bonus              0.230520            0.417241
# Should_Receive_Bonus                         -0.259412           -0.181171
#
#                                   Number_of_Bonuses_Received  \
# Winning_percentage                                 -0.020859
# Days_Since_Last_Bet                                 0.160583
# Active_Days                                         0.134548
# Total_Number_of_Bets                                0.360399
# Total_Amount_Wagered                                0.642656
# Average_Bet_Amount                                  0.892831
# Number_of_Bonuses_Received                          1.000000
# Amount_of_Bonuses_Received                          0.939942
# Revenue_from_Bonuses                                0.819982
# Increase_in_Bets_After_Bonus                        0.686857
# Increase_in_wagering_after_Bonus                    0.664088
# Should_Receive_Bonus                               -0.083974
#
#                                   Amount_of_Bonuses_Received  \
# Winning_percentage                                 -0.016889
# Days_Since_Last_Bet                                 0.110734
# Active_Days                                         0.099675
# Total_Number_of_Bets                                0.229414
# Total_Amount_Wagered                                0.451784
# Average_Bet_Amount                                  0.715258
# Number_of_Bonuses_Received                          0.939942
# Amount_of_Bonuses_Received                          1.000000
# Revenue_from_Bonuses                                0.955878
# Increase_in_Bets_After_Bonus                        0.869513
# Increase_in_wagering_after_Bonus                    0.847930
# Should_Receive_Bonus                               -0.047637
#
#                                   Revenue_from_Bonuses  \
# Winning_percentage                           -0.014581
# Days_Since_Last_Bet                           0.079984
# Active_Days                                   0.074916
# Total_Number_of_Bets                          0.166266
# Total_Amount_Wagered                          0.339687
# Average_Bet_Amount                            0.569846
# Number_of_Bonuses_Received                    0.819982
# Amount_of_Bonuses_Received                    0.955878
# Revenue_from_Bonuses                          1.000000
# Increase_in_Bets_After_Bonus                  0.976077
# Increase_in_wagering_after_Bonus              0.965272
# Should_Receive_Bonus                         -0.033277
#
#                                   Increase_in_Bets_After_Bonus  \
# Winning_percentage                                   -0.011880
# Days_Since_Last_Bet                                   0.053157
# Active_Days                                           0.052962
# Total_Number_of_Bets                                  0.109312
# Total_Amount_Wagered                                  0.237462
# Average_Bet_Amount                                    0.431737
# Number_of_Bonuses_Received                            0.686857
# Amount_of_Bonuses_Received                            0.869513
# Revenue_from_Bonuses                                  0.976077
# Increase_in_Bets_After_Bonus                          1.000000
# Increase_in_wagering_after_Bonus                      0.998452
# Should_Receive_Bonus                                 -0.020351
#
#                                   Increase_in_wagering_after_Bonus  \
# Winning_percentage                                       -0.011462
# Days_Since_Last_Bet                                       0.051679
# Active_Days                                               0.050835
# Total_Number_of_Bets                                      0.106594
# Total_Amount_Wagered                                      0.230520
# Average_Bet_Amount                                        0.417241
# Number_of_Bonuses_Received                                0.664088
# Amount_of_Bonuses_Received                                0.847930
# Revenue_from_Bonuses                                      0.965272
# Increase_in_Bets_After_Bonus                              0.998452
# Increase_in_wagering_after_Bonus                          1.000000
# Should_Receive_Bonus                                     -0.020005
#
#                                   Should_Receive_Bonus
# Winning_percentage                            0.366710
# Days_Since_Last_Bet                           0.100379
# Active_Days                                   0.142909
# Total_Number_of_Bets                         -0.001881
# Total_Amount_Wagered                         -0.259412
# Average_Bet_Amount                           -0.181171
# Number_of_Bonuses_Received                   -0.083974
# Amount_of_Bonuses_Received                   -0.047637
# Revenue_from_Bonuses                         -0.033277
# Increase_in_Bets_After_Bonus                 -0.020351
# Increase_in_wagering_after_Bonus             -0.020005
# Should_Receive_Bonus                          1.000000

# %%
df.columns
# Out:
# Index(['Winning_percentage', 'Days_Since_Last_Bet', 'Active_Days',
#        'Total_Number_of_Bets', 'Total_Amount_Wagered', 'Average_Bet_Amount',
#        'Number_of_Bonuses_Received', 'Amount_of_Bonuses_Received',
#        'Revenue_from_Bonuses', 'Increase_in_Bets_After_Bonus',
#        'Increase_in_wagering_after_Bonus', 'Should_Receive_Bonus'],
#       dtype='object')

# %%
X = df[['Winning_percentage', 'Average_Bet_Amount',
       'Number_of_Bonuses_Received', 'Amount_of_Bonuses_Received',
       'Revenue_from_Bonuses']]

# %%
X_1 = df_1[['Winning_percentage', 'Average_Bet_Amount',
       'Number_of_Bonuses_Received', 'Amount_of_Bonuses_Received',
       'Revenue_from_Bonuses']]

# %%
X_1.head()
# Out:
#    Winning_percentage  Average_Bet_Amount  Number_of_Bonuses_Received  \
# 0                  43               244.0                        40.0
# 1                  73               707.0                        76.0
# 2                  20               831.0                        92.0
# 3                  56               904.0                        88.0
# 4                   7               223.0                        51.0
#
#    Amount_of_Bonuses_Received  Revenue_from_Bonuses
# 0                       996.0                4964.0
# 1                       735.0                3885.0
# 2                       555.0                3070.0
# 3                       462.0                2478.0
# 4                       984.0                4940.0

# %%
X_1.shape
# Out:
# (5000, 5)

# %%
y = df[['Should_Receive_Bonus']]

# %%
y_1 = df_1[['Should_Receive_Bonus']]

# %%
def evaluate_clf(true, predicted):
    acc = accuracy_score(true, predicted) # Calculate Accuracy
    f1 = f1_score(true, predicted) # Calculate F1-score
    precision = precision_score(true, predicted) # Calculate Precision
    recall = recall_score(true, predicted)  # Calculate Recall
    roc_auc = roc_auc_score(true, predicted) #Calculate Roc
    return acc, f1 , precision, recall, roc_auc

# %%
models = {
    "Random Forest": RandomForestClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Logistic Regression": LogisticRegression(),
     "K-Neighbors Classifier": KNeighborsClassifier(),
    "XGBClassifier": XGBClassifier(), 
     "CatBoosting Classifier": CatBoostClassifier(verbose=False),
     "Support Vector Classifier": SVC(),
    "AdaBoost Classifier": AdaBoostClassifier()

}

# %%
def evaluate_models(X, y, models):
    # separate dataset into train and test
    X_train, X_test, y_train, y_test = train_test_split(X_1,y_1,test_size=0.2,random_state=42)
    
    models_list = []
    accuracy_list = []
    auc= []
    
    for i in range(len(list(models))):
        model = list(models.values())[i]
        model.fit(X_train, y_train) # Train model

        # Make predictions
        y_train_pred = model.predict(X_train)
        y_test_pred = model.predict(X_test)

        # Training set performance
        model_train_accuracy, model_train_f1,model_train_precision,\
        model_train_recall,model_train_rocauc_score=evaluate_clf(y_train ,y_train_pred)


        # Test set performance
        model_test_accuracy,model_test_f1,model_test_precision,\
        model_test_recall,model_test_rocauc_score=evaluate_clf(y_test, y_test_pred)

        print(list(models.keys())[i])
        models_list.append(list(models.keys())[i])

        print('Model performance for Training set')
        print("- Accuracy: {:.4f}".format(model_train_accuracy))
        print('- F1 score: {:.4f}'.format(model_train_f1)) 
        print('- Precision: {:.4f}'.format(model_train_precision))
        print('- Recall: {:.4f}'.format(model_train_recall))
        print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

        print('----------------------------------')

        print('Model performance for Test set')
        print('- Accuracy: {:.4f}'.format(model_test_accuracy))
        accuracy_list.append(model_test_accuracy)
        print('- F1 score: {:.4f}'.format(model_test_f1))
        print('- Precision: {:.4f}'.format(model_test_precision))
        print('- Recall: {:.4f}'.format(model_test_recall))
        print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))
        auc.append(model_test_rocauc_score)
        print('='*35)
        print('\n')
        
    report=pd.DataFrame(list(zip(models_list, accuracy_list)), columns=['Model Name', 'Accuracy']).sort_values(by=['Accuracy'], ascending=False)
    return report

# %%
evaluate_models(X_1, y_1, models)
# Out:
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest
# Model performance for Training set
# - Accuracy: 0.9995
# - F1 score: 0.9995
# - Precision: 0.9995
# - Recall: 0.9995
# - Roc Auc Score: 0.9995
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9020
# - F1 score: 0.9089
# - Precision: 0.9226
# - Recall: 0.8956
# - Roc Auc Score: 0.9026
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Accuracy: 0.9995
# - F1 score: 0.9995
# - Precision: 1.0000
# - Recall: 0.9991
# - Roc Auc Score: 0.9995
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8930
# - F1 score: 0.9010
# - Precision: 0.9103
# - Recall: 0.8919
# - Roc Auc Score: 0.8931
# ===================================
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Gradient Boosting
# Model performance for Training set
# - Accuracy: 0.9187
# - F1 score: 0.9229
# - Precision: 0.9266
# - Recall: 0.9191
# - Roc Auc Score: 0.9187
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8980
# - F1 score: 0.9056
# - Precision: 0.9157
# - Recall: 0.8956
# - Roc Auc Score: 0.8982
# ===================================
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Logistic Regression
# Model performance for Training set
# - Accuracy: 0.8890
# - F1 score: 0.8938
# - Precision: 0.9046
# - Recall: 0.8832
# - Roc Auc Score: 0.8894
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8870
# - F1 score: 0.8943
# - Precision: 0.9140
# - Recall: 0.8755
# - Roc Auc Score: 0.8882
# ===================================
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\neighbors\_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# K-Neighbors Classifier
# Model performance for Training set
# - Accuracy: 0.9257
# - F1 score: 0.9292
# - Precision: 0.9370
# - Recall: 0.9215
# - Roc Auc Score: 0.9260
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8790
# - F1 score: 0.8866
# - Precision: 0.9079
# - Recall: 0.8663
# - Roc Auc Score: 0.8803
# ===================================
#
#
# XGBClassifier
# Model performance for Training set
# - Accuracy: 0.9838
# - F1 score: 0.9846
# - Precision: 0.9872
# - Recall: 0.9820
# - Roc Auc Score: 0.9839
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9090
# - F1 score: 0.9164
# - Precision: 0.9190
# - Recall: 0.9139
# - Roc Auc Score: 0.9085
# ===================================
#
#
# CatBoosting Classifier
# Model performance for Training set
# - Accuracy: 0.9490
# - F1 score: 0.9514
# - Precision: 0.9587
# - Recall: 0.9442
# - Roc Auc Score: 0.9493
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9030
# - F1 score: 0.9098
# - Precision: 0.9244
# - Recall: 0.8956
# - Roc Auc Score: 0.9037
# ===================================
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Support Vector Classifier
# Model performance for Training set
# - Accuracy: 0.8175
# - F1 score: 0.8245
# - Precision: 0.8386
# - Recall: 0.8109
# - Roc Auc Score: 0.8179
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8160
# - F1 score: 0.8303
# - Precision: 0.8364
# - Recall: 0.8242
# - Roc Auc Score: 0.8152
# ===================================
#
#
# AdaBoost Classifier
# Model performance for Training set
# - Accuracy: 0.8930
# - F1 score: 0.8970
# - Precision: 0.9133
# - Recall: 0.8813
# - Roc Auc Score: 0.8937
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8890
# - F1 score: 0.8956
# - Precision: 0.9207
# - Recall: 0.8718
# - Roc Auc Score: 0.8907
# ===================================
#                   Model Name  Accuracy
# 5              XGBClassifier     0.909
# 6     CatBoosting Classifier     0.903
# 0              Random Forest     0.902
# 2          Gradient Boosting     0.898
# 1              Decision Tree     0.893
# 8        AdaBoost Classifier     0.889
# 3        Logistic Regression     0.887
# 4     K-Neighbors Classifier     0.879
# 7  Support Vector Classifier     0.816

# %%
#Initialize few parameter for Hyperparamter tuning
xgboost_params = {
    'max_depth':range(3,10,2),
    'min_child_weight':range(1,6,2)
}

rf_params = {
    "max_depth": [10, 12, None, 15, 20],
    "max_features": ['sqrt', 'log2', None],
    "n_estimators": [10, 50, 100, 200]
}

knn_params = {
    "algorithm": ['auto', 'ball_tree', 'kd_tree','brute'],
    "weights": ['uniform', 'distance'],
    "n_neighbors": [3, 4, 5, 7, 9],
}

# %%
# Models list for Hyperparameter tuning
randomcv_models = [
    ('XGBoost', XGBClassifier(), xgboost_params),
    ("RF", RandomForestClassifier(), rf_params),
    ("KNN", KNeighborsClassifier(), knn_params)
]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2, 
                                   n_jobs=-1)
    random.fit(X, y)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 60 is smaller than n_iter=100. Running 60 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 40 is smaller than n_iter=100. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# ---------------- Best Params for XGBoost -------------------
# {'min_child_weight': 1, 'max_depth': 3}
# ---------------- Best Params for RF -------------------
# {'n_estimators': 200, 'max_features': 'log2', 'max_depth': 10}
# ---------------- Best Params for KNN -------------------
# {'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'auto'}
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\neighbors\_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
model_param
# Out:
# {'XGBoost': {'min_child_weight': 1, 'max_depth': 3},
#  'RF': {'n_estimators': 200, 'max_features': 'log2', 'max_depth': 10},
#  'KNN': {'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'auto'}}

# %%
from sklearn.metrics import roc_auc_score,roc_curve
best_models = {
    "Random Forest Classifier": RandomForestClassifier(**model_param['RF']),
    "KNeighborsClassifier": KNeighborsClassifier(**model_param['KNN']),
    "XGBClassifier": XGBClassifier(**model_param['XGBoost'],n_jobs=-1),
}
tuned_report =evaluate_models(X=X, y=y, models=best_models)
# Out:
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Classifier
# Model performance for Training set
# - Accuracy: 0.8798
# - F1 score: 0.9167
# - Precision: 0.8969
# - Recall: 0.9373
# - Roc Auc Score: 0.8395
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8210
# - F1 score: 0.8776
# - Precision: 0.8641
# - Recall: 0.8917
# - Roc Auc Score: 0.7655
# ===================================
#
#
# KNeighborsClassifier
# Model performance for Training set
# - Accuracy: 0.8882
# - F1 score: 0.9203
# - Precision: 0.9261
# - Recall: 0.9146
# - Roc Auc Score: 0.8698
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.7970
# - F1 score: 0.8539
# - Precision: 0.8864
# - Recall: 0.8236
# - Roc Auc Score: 0.7761
# ===================================
# c:\Users\pouru\anaconda3\envs\bonus_allocation_system\lib\site-packages\sklearn\neighbors\_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# XGBClassifier
# Model performance for Training set
# - Accuracy: 0.8660
# - F1 score: 0.9061
# - Precision: 0.8966
# - Recall: 0.9157
# - Roc Auc Score: 0.8313
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8320
# - F1 score: 0.8838
# - Precision: 0.8802
# - Recall: 0.8875
# - Roc Auc Score: 0.7884
# ===================================

# %%
tuned_report
# Out:
#                  Model Name  Accuracy
# 2             XGBClassifier     0.832
# 0  Random Forest Classifier     0.821
# 1      KNeighborsClassifier     0.797

# %%
df_2 = pd.read_csv("total_clean_data.csv")

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   index                             5000 non-null   int64
#  1   customer_id                       5000 non-null   int64
#  2   first_name                        5000 non-null   object
#  3   last_name                         5000 non-null   object
#  4   country                           5000 non-null   object
#  5   age                               5000 non-null   int64
#  6   gender                            5000 non-null   object
#  7   income_level                      5000 non-null   int64
#  8   Winning_percentage                5000 non-null   int64
#  9   Days_Since_Last_Bet               5000 non-null   float64
#  10  Active_Days                       5000 non-null   float64
#  11  Total_Number_of_Bets              5000 non-null   float64
#  12  Total_Amount_Wagered              5000 non-null   float64
#  13  Average_Bet_Amount                5000 non-null   float64
#  14  Number_of_Bonuses_Received        5000 non-null   float64
#  15  Amount_of_Bonuses_Received        5000 non-null   float64
#  16  Revenue_from_Bonuses              5000 non-null   float64
#  17  Increase_in_Bets_After_Bonus      5000 non-null   float64
#  18  Increase_in_wagering_after_Bonus  5000 non-null   float64
#  19  Should_Receive_Bonus              5000 non-null   int64
# dtypes: float64(10), int64(6), object(4)
# memory usage: 781.4+ KB
